# %% [markdown]
# <center><h1>𝓛𝓲𝓷𝓮𝓪𝓻 𝓡𝓮𝓰𝓻𝓮𝓼𝓼𝓼𝓲𝓸𝓷</h1></center>

# %% [markdown]
# * It's a **Supervised** approach, where we give the input and output data.
# * **Regression** is just a kind of **relationship finder** you can think. It able to find the relationship between two dataset or **two or more features**. For example: It helsp Independent features is having relantionship between dependent features are not.
# * To understand clearly, Let's plot the data in Cartesian co-ordinate:
#
# <center><img src="https://statsandr.com/blog/multiple-linear-regression-made-simple/index_files/figure-html/unnamed-chunk-6-1.png" width="600"/></center>
#
# **Here, we have x and y axis, you can consider, y is proportional x:**
#
# ## $$ y \propto x $$
# **To remove the propotional constant we need to add some constant:**
#
# ## $$ y = mx $$
#
# **Sometimes, the m value not give the exact results what we need, so we need to some error term:**
#
# ## $$ y = mx \pm e $$
#
# **Let's change the equation little bit:** (Just changing the notation):
# ## $$ y = m*x + c $$

# %% [markdown]
# **This is the equation of straight line, Let's intrept the equation more detail:**
#
# ## if c = 0 $$ y = mx $$
# ## Then, $$ m = (y/x) $$

# %% [markdown]
# * **M** is trying to represent **slope** at any point of line.
# * **C** is trying to represent where the slope of line is originating.
#
# **M** -> Slope (Every changes of **x** by what rate of my **y** is changing), In wild, you can able to get multiple names of M, some of them are, tanget, dy/dx and slope.
#
# #### Slope:
#
# <img src="https://www.mathwarehouse.com/animated-gifs/images/slope-never-changes-line.gif" width="300"/>
#
# #### Intercept:
#
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS7iwRR2sWl6CVeECoe0qLuOxfXE_KNVvqX4NyLF9cRoeQtU2PdQlYFm_sKZm8rLUHYmug&usqp=CAU" width="300"/>
#
# **Small recap**:
#  $$ y \propto x $$
#  $$ y = mx $$
#  $$ y = mx \pm e $$
#  $$ y = m*x + c $$

# %% [markdown]
# **Formula for finding m and c**
# ##  $$ m = \frac{n\sum xy - \sum x\sum y}{n\sum x^2 - (\sum x)^2} $$
#
# ## $$ c = n\sum y - m*\sum x $$
#
#
# **Equation of straight line is all about draw a line between two or more features, if we have a good relationship between dependent and Independent features you can use this, but you will get more lines that fitted on the graph**.
#
# <center><img src="https://cdn.corporatefinanceinstitute.com/assets/multiple-linear-regression.png" width="400"/></center>
#
# When you are trying to use line formula, what we have seen before you will end with multiple lines because you have more data in your hand. How do we decide which line gives the good results? This is why Linear regression comes in, LR model helps to find which line is best by doing some process. Let's discuss the process in more detail.

# %% [markdown]
# You can think, multiple lines are multiple values of m and c, becasue if you have m and c you can able to draw a line. **m** and **c** helps to draw a line. Nothing but if you know tangent and intercept you can draw a line easily!.

# %% [markdown]
# ## How do we find the Best Line?
#
# **Consider This is our Dataset**
# <center><img src="https://www.statology.org/wp-content/uploads/2018/09/weight_height.jpg" width="300"/></center>

# %% [markdown]
# Here, we are going to find the m and c. And the best line by using this example!
#
# First find out the m and c for first 2 rows and write it some where, Then find the m and c for next 2 rows and write it some where. Now we have two equations, and give the x value as (Height) and find the output. Hope you got the output, and compare your output to the original weight, Which output gives the lesser difference between your output (yhat) and the original output(y), you can take the m and c value as the final equation.
#
# Here, we need to reduce the error between the predicted and actual output. But how can we represent this in number? By using the residuals, we can represent the difference in number format!
#
# **Residual is nothing but actual value minus the predicted value**.
#
# ## $$ r = (y - \hat{y} ) $$
# Let's expand this equation
# ## $$ r = (y - (mx + c)) $$
# We, may have more negative and postive terms, so add square to neglect
# ## $$ r = (y - (mx + c))^2 $$
#
# Here, we don't have only one recore, we will end up with multiple sequence of records, so we need to add everything.
# ## $$ r^2 = \sum_{i=1}^{m}  (y - (mx + c))^2 $$

# %% [markdown]
# * **Step1: Find M anc C value**
# * **Step2: Find the Best M and C values by using mutliple equation**
# * **Step3: Represent the Error term in mathematical way**
#
# This is fine, But we can do this steps when we have just 10 records like the previous table, But if we have 1k records or 1M records how do we do this manually, here's the **Linear Regression** comes in mind, it will help us to find the best fit line by doing all the steps for all the records by using the Gradient Descent algorithm.

# %% [markdown]
# <center><img src="https://vidyasagar.rbind.io/post/2019-06-14-gradient-descent-from-scratch-and-visualization_files/figure-html/unnamed-chunk-1-1.gif" width="400"/></center>
#
# You can consider, gradient descent helps to find the best fit line by using the r2 by plotting in the Graph, when we are reaching the very less error, we can consider the equation is good enough to calculate the new values.
#
# Some maths behind the G.D
#
# ###  $ \hat{y} = m*x + b$
#
# ![](http://chrisjmccormick.files.wordpress.com/2014/03/scalarmultipleandsumrules.png)
#
# ![](http://mccormickml.com/assets/GradientDescent/PowerRule.png)
#
# ![](http://mccormickml.com/assets/GradientDescent/ChainRule.png)
#
# ## gradient with respect to m
#
# ### $ \frac  {\partial SSE }{\partial m} =   \frac{\partial  }{\partial m} ( \frac {1} {n}  \sum_{i=1}^{n}(y_{i}- (mx_i + b))^2 )  $
#
# ### $=  \frac {1} {n}  \sum_{i=1}^{n} \frac{\partial  }{\partial m}  (y_{i}- (mx_i + b))^2   $
# ### $=  \frac {1} {n}  \sum_{i=1}^{n} 2 (y_{i}- (mx_i + b)) \frac{\partial  }{\partial m}  (y_{i}- (mx_i + b)) $
# ### $=  \frac {1} {n}  \sum_{i=1}^{n} 2 (y_{i}- (mx_i + b)) (-x_i) $
# ### $=  \frac {1} {n}  \sum_{i=1}^{n} -2 x_i(y_{i}- (mx_i + b))  $
#
#
#
#
# ## gradient with respect to b
#
# ### $ \frac{\partial SSE }{\partial b} =   \frac{\partial  }{\partial b} ( \frac {1} {n}  \sum_{i=1}^{n}(y_{i}- (mx_i + b))^2 )  $
#
# ### $=  \frac {1} {n}  \sum_{i=1}^{n} \frac{\partial  }{\partial b}  (y_{i}- (mx_i + b))^2   $
# ### $=  \frac {1} {n}  \sum_{i=1}^{n} 2 (y_{i}- (mx_i + b)) \frac{\partial  }{\partial b}  (y_{i}- (mx_i + b)) $
# ### $=  \frac {1} {n}  \sum_{i=1}^{n} 2 (y_{i}- (mx_i + b)) (-1) $
# ### $=  \frac {1} {n}  \sum_{i=1}^{n} -2 (y_{i}- (mx_i + b))  $

# %%
# Let's try to do this in our code!
#import the librabry
import pandas as pd 
import matplotlib.pyplot as plt

# Read the csv 
score_data=pd.read_csv("GAP Prediction.csv")

# Preprocess 
#return a numpy array 
X=score_data["SAT"].values.reshape(-1,1)
Y=score_data["GPA"].values.reshape(-1,1)

# split the data 
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.25,random_state=42)

# Let's do the Gradient Descent: 
def gradient (epochs,learning_rate,xtrain,ytrain):
    m=0
    b=0
    N=xtrain.shape[0]
    
    for i in range(epochs):
        y_pred= (m*xtrain)+ b
        d_slope=(-2/N)*sum(xtrain*(ytrain-y_pred))
        d_intercept=(-2/N)*sum(ytrain-y_pred)
        m=m - (learning_rate * d_slope)
        b=b - (learning_rate * d_intercept)
        
    return m,b

#pass different values for epoch and learning rate - they are to ounf using trail/error method there is no fixed value for it 
m,b=gradient (300,0.0000001,xtrain,ytrain)

# %%
# Let's create a equation from the gradient descent: 
m=m[0]
b=b[0]

ypred=(m*xtest)+b

# %%
# Let's compare predicted and real value 
from IPython import display 
display.set_matplotlib_formats('svg')

plt.scatter(X,Y,color='b')
plt.plot(xtest,ypred)
plt.xlabel("SAT")
plt.ylabel("GPA");
# Out:
# C:\Users\aravi\AppData\Local\Temp/ipykernel_23376/3215884902.py:3: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   display.set_matplotlib_formats('svg')

# %%
# How we measure the prediction? 
# Here's comes in some metrics, Let's see

# %% [markdown]
# ## MAE,MSE,RMSE
#
# <b> Measure of spread that tells you how scattered your data is around the regression line  ,measures the overall accuracy of the model </b>
#
#
# ### $ \text{MAE}(y, \hat{y}) = \frac{1}{n_{\text{samples}}} \sum_{i=1}^{n_{\text{samples}}} \left| y_i - \hat{y}_i \right|. $
#
# ### $ \text{MSE}(y, \hat{y}) = \frac{1}{n_\text{samples}} \sum_{i=1}^{n_\text{samples}} (y_i - \hat{y}_i)^2 $
#
# ### $ \text{RMSE}(y, \hat{y}) = \frac{1}{n_\text{samples}} \sqrt {\sum_{i=1}^{n_\text{samples}} (y_i - \hat{y}_i)^2 }$

# %%
# Let's do this in code 
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# MAE 
print("MAE",mean_absolute_error(ytest,ypred))

# MSE
print("\nMSE",mean_squared_error(ytest,ypred))

# RMSE 
from  math import sqrt as sqrt
print("\nRMSE",sqrt(mean_squared_error(ytest,ypred)))

# The more the less value, more the model is accurate
# Out:
# MAE 0.14802953582573342
#
# MSE 0.041922887659480906
#
# RMSE 0.20475079403870675

# %% [markdown]
# ## How well the model fits the data.
# (You can consider this is how we measure accuracy of our model).
#
# ### $ \hat{y}_i\text{ : predicted value} $
#
# ### $ \bar{y} \text{ : mean of our observation} = \frac{1}{n} \sum_{i=1}^{n} y_i $
#
# ### $ {y}_i\text{ : actual value} $
# ### $ R^2(y, \hat{y}) = 1 - \frac{RSS}{TSS} $
# ### $ RSS =  {\sum_{i=1}^{n} (y_i - \hat{y}_i)^2} $
# ###  $ TSS =  {\sum_{i=1}^{n} (y_i - \bar{y})^2} $
#
# Residual Summation of Square -> how good is the model with independent variable
#
# Total Summation of Square  -> how good is the model without slope but with the y intercept passing over the mean

# %% [markdown]
# <center><img src="https://i.stack.imgur.com/LpHPy.png" width="600"/></center>
#
# <center><img src="https://learnche.org/pid/_images/ANOVA-graphically.png" width="600"/></center>
#
# ### $ R^2(y, \hat{y}) = 1 - \frac{\sum_{i=1}^{n} (y_i - \hat{y}_i)^2}{\sum_{i=1}^{n} (y_i - \bar{y})^2} $
#
# -   <b>  how much error we eliminate when we choose to use a regression line instead of a perfectly horizontal line </b>
#
# - <b> $ R^2 $ tells percentage variation in y which is explained by all the x variables together<b>
#
# - <b>   It assumes every independent variable in the model helps to explain variation in the dependent variable .In reality, some independent variables (predictors) don't help to explain dependent (target) variable. In other words, some variables do not contribute in predicting target variable.<b>
#
# - <b> 0% measures zero predictive power of the model <b>
#
# - <b> 100% the model explains all the variation of the target variable <b>
#
# - <b> coefficient of determination of 60% tells you that the regression line is much closer to many of the data points than the horizontal line is to those data points <b>
#
# - <b> range - ranges from 0 to 1  sometimes can get negative value as well <b>
#
# - <b> higher  $ R^2 $ value the better model ,sometimes expressed as percentage <b>
#
#
#
#
# # Problem
#
# - The inclusion of numerous independent variables, even though they have very little explanatory power on the dependent variable, will increase the value of $ R^2 $ even if the independent variable is insignificant

# %%
r2= r2_score(ytest,ypred)
print("R^2 (coefficient of determination ,)",r2)
# Out:
# R^2 (coefficient of determination ,) 0.5294885793076934

# %% [markdown]
# ### $ Adjusted   R^2  =  1- \frac {(1-R^2) (1-N)}{(N-p-1)} $
#
#  $R^2  : R^2 value  $
#
# p : No of predictors /independent varaibles
#
# N : total samples
#
# Adjusted R2 will always be less than or equal to R2.

# %%
# THERE IS NO LIBRARAY FOR ADJUSTED R2, Let's do manually! 
N=len(ytest)
p=1
ar2=1-((1-r2)*(1-N))/(N-p-1)

print("Ajusted r2" , ar2)
# Out:
# Ajusted r2 1.4952751796761121

# %% [markdown]
# ||Coefficient of Correlation |Coefficient of determination (r square)|ajusted r square|
# |:----:|:-----|:----:|----:|
# |Definiton|measures the strength and the direction of a linear relationship between two variables (x and y) |It provides percentage variation in y which is explained by all the x variables together , indicates strength of Linear Regression model |It measures the proportion of variation explained by only those independent variables that really help in explaining the dependent variable . - It penalizes you for adding independent variable that do not help in predicting the dependent variable.|
# |range|possible values between -1 to  1|possible values between -infinity to  1 ,sometimse might have negative value |It provides percentage variation in y which is explained by all the x variables together , indicates strength of Linear Regression model |
# |problem||Every time you add a independent variable to a model, the R-squared increases, even if the independent variable is insignificant. It never declines|Adjusted R-squared increases only when independent variable is significant and affects dependent variable|

# %%
# Let's do this by normal method!
from sklearn.linear_model import LinearRegression

# Initialize 
lr=LinearRegression()

# Fit to our training data 
model=lr.fit(xtrain,ytrain)

# Predict the new values
ypred=model.predict(xtest)

# %%
# Then all the accuracy and metrics are same thing, what we have seen before. 
print("MAE",mean_absolute_error(ytest,ypred))
# Out:
# MAE 0.15548838076312174

# %% [markdown]
# ## Save the model using pickel
#
# Python pickle module is used for serializing and de-serializing python object structures. The process to converts any kind of python objects (list, dict, etc.) into byte streams (0s and 1s) is called pickling or serialization or flattening or marshalling. We can converts the byte stream (generated through pickling) back into python objects by a process called as unpickling.
#
# Why Pickle?: In real world sceanario, the use pickling and unpickling are widespread as they allow us to easily transfer data from one server/system to another and then store it in a file or database.
#
# object serialization This process / procedure of saving a ML Model is also known as object serialization - representing an object with a stream of bytes, in order to store it on disk, send it over a network or save to a database.
#
# deserialization While the restoring/reloading of ML Model procedure is known as deserialization.

# %% [markdown]
# ```Python
# import pickle
# pickel_m = Your Path Here"
#
# with open(pickel_m, 'wb') as file:
#     pickle.dump(model, file)
# ```

# %% [markdown]
# This is how you will implement the linear regression, but before this you need to know the basic assumption for using linear regression:
#
# 1. Somehow relationship between x and y features.
# 2. Mean of Residual should be zero.
# 3. Error term not should be correlated.
# 4. x and residual must be un correlated. This is also called (exogeneidy)
# 5. Error term must showcase constant variance. This is also called (homoscedasicity).
# 6. NO Multi collinearity. (Independent variables not to be correlated with each other)
# 7. Error terms suppose to be normally distributed.
#
# -This all depends on Gradient descent, make sure have a good knowlege in GD.
